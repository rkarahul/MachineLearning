# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('E:\\DUCAT_PYTHON COURSE\\dataset\\analysis\\restaurant.csv')
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sb.scatterplot(x=df.total_bill,y=df.tip,hue=df.gender)
plt.xlabel('Total_Bill')
plt.ylabel('Tip')
plt.show()

# %%
sb.scatterplot(x=df.total_bill,y=df.tip,hue=df.day)
plt.xlabel('Total_Bill')
plt.ylabel('Tip')
plt.show()

# %%
sb.scatterplot(x=df.total_bill,y=df.tip,style=df.gender)
plt.xlabel('Total_Bill')
plt.ylabel('Tip')
plt.show()

# %%
sb.scatterplot(x=df.total_bill,y=df.tip,hue=df.gender,style=df.day)
plt.xlabel('Total_Bill')
plt.ylabel('Tip')
plt.show()

# %%
# Bar Chart
sb.countplot(x=df.day)
plt.show()

# %%
sb.countplot(x=df.day,hue=df.time)
plt.show()

# %%
sb.countplot(x=df.day,order=['Thur','Fri','Sat','Sun'])
plt.show()

# %%
sb.countplot(y=df.day,order=['Thur','Fri','Sat','Sun'])
plt.show()

# %%
# Joinplot===> Scatter+histogram
sb.jointplot(x=df.total_bill,y=df.tip)
plt.show()

# %%
#pairplot===>histogram+scatter for each pair of numeric cols
sb.pairplot(df)
plt.show()

# %%
#boxplot-->outliers detection in numeric col(s)
import numpy as np
x=np.random.randint(1,50,100)
#y=np.random.randint(1,50,100)

x[10]=150
x[20]=155
x[30]=-50
#sb.boxplot(x)
sb.boxplot(x,orient='h')
#sb.boxplot([x,y])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#boxplot-->outliers detection in numeric col(s)
import numpy as np
x=np.random.randint(1,50,100)
y=np.random.randint(1,50,100)

x[10]=150
x[20]=155
x[30]=-50
#sb.boxplot(x)
#sb.boxplot(x,orient='h')
sb.boxplot([x,y])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8816\1187716910.py in <module>
#       9 #sb.boxplot(x)
#      10 #sb.boxplot(x,orient='h')
# ---> 11 sb.boxplot([x,y])
#      12 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
#heatmap
matrix=np.random.randint(1,10,(10,10))
matrix
# Out:
# array([[9, 7, 5, 6, 7, 6, 6, 6, 9, 5],
#        [1, 5, 7, 3, 8, 6, 4, 5, 8, 8],
#        [5, 7, 1, 5, 4, 5, 6, 3, 7, 9],
#        [8, 7, 9, 2, 8, 5, 2, 1, 1, 7],
#        [4, 6, 4, 8, 2, 2, 6, 2, 5, 5],
#        [1, 3, 7, 7, 6, 9, 2, 7, 6, 7],
#        [5, 6, 1, 4, 1, 6, 2, 3, 2, 3],
#        [9, 3, 8, 9, 5, 8, 1, 7, 9, 8],
#        [7, 3, 2, 7, 9, 9, 8, 3, 2, 6],
#        [9, 5, 6, 8, 9, 1, 2, 5, 7, 3]])

# %%
sb.heatmap(matrix)
plt.show()

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sb.heatmap(df.corr())
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.subplot(2,2,1)
sb.countplot(x=df.day)

plt.subplot(2,2,2)
sb.scatterplot(x=df.total_bill,y=df.tip)

plt.subplot(2,2,4)
x=np.random.randint(1,50,100)
x[10]=150
x[20]=155
x[30]=-50
sb.boxplot(x)

#plt.show()
plt.savefig("E:/mix.png")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
