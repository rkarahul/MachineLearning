# %% [markdown]
# # Data Manipulation

# %% [raw]
# Data Manipulation
# - we can add new row/col
# - we can perform calculations on existing data
# - we perform any activity that modify data

# %%
import pandas as pd

# %%
df  =pd.read_csv("E:\\DUCAT_PYTHON COURSE\\dataset\\analysis\\restaurant.csv")

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# how to add/update a column
#df['col_lable'] =  1d array like

df['tax']=df.total_bill*.05

# %%
df['tax']
# Out:
# 0      0.8495
# 1      0.5170
# 2      1.0505
# 3      1.1840
# 4      1.2295
#         ...
# 239    1.4515
# 240    1.3590
# 241    1.1335
# 242    0.8910
# 243    0.9390
# Name: tax, Length: 244, dtype: float64

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size     tax
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.8495
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.5170
# 2         21.01  3.50    Male     No   Sun  Dinner     3  1.0505
# 3         23.68  3.31    Male     No   Sun  Dinner     2  1.1840
# 4         24.59  3.61  Female     No   Sun  Dinner     4  1.2295
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  1.4515
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.3590
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.1335
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.8910
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.9390
#
# [244 rows x 8 columns]

# %%
df.drop('tax',axis=1,inplace=True)

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
def cal_tax(bill):
    if(bill<10):
        return bill*.05
    elif(bill>=10 and bill<20):
        return bill*.10
    else:
        return bill*.15

# %%
cal_tax(9)
# Out:
# 0.45

# %%
cal_tax(12)
# Out:
# 1.2000000000000002

# %%
cal_tax(50)
# Out:
# 7.5

# %%
df['tax']=df.total_bill.apply(cal_tax)
df
# Out:
#      total_bill   tip  gender smoker   day    time  size     tax
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1.6990
# 1         10.34  1.66    Male     No   Sun  Dinner     3  1.0340
# 2         21.01  3.50    Male     No   Sun  Dinner     3  3.1515
# 3         23.68  3.31    Male     No   Sun  Dinner     2  3.5520
# 4         24.59  3.61  Female     No   Sun  Dinner     4  3.6885
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  4.3545
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  4.0770
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  3.4005
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1.7820
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.8780
#
# [244 rows x 8 columns]

# %%
df['final_bill']=df.total_bill+df.tax

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size     tax  final_bill
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1.6990     18.6890
# 1         10.34  1.66    Male     No   Sun  Dinner     3  1.0340     11.3740
# 2         21.01  3.50    Male     No   Sun  Dinner     3  3.1515     24.1615
# 3         23.68  3.31    Male     No   Sun  Dinner     2  3.5520     27.2320
# 4         24.59  3.61  Female     No   Sun  Dinner     4  3.6885     28.2785
# ..          ...   ...     ...    ...   ...     ...   ...     ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  4.3545     33.3845
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  4.0770     31.2570
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  3.4005     26.0705
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1.7820     19.6020
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.8780     20.6580
#
# [244 rows x 9 columns]

# %%
df['final_bill']=df.total_bill+df.tip

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size     tax  final_bill
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1.6990       18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3  1.0340       12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3  3.1515       24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  3.5520       26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  3.6885       28.20
# ..          ...   ...     ...    ...   ...     ...   ...     ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  4.3545       34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  4.0770       29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  3.4005       24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1.7820       19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.8780       21.78
#
# [244 rows x 9 columns]

# %%
# how to add/update new col
#df.loc[index]=  1d array like
df.loc[500]=[20,5,'male','no','Fri','Lunch',3,2,22]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size     tax  final_bill
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1.6990       18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3  1.0340       12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3  3.1515       24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  3.5520       26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  3.6885       28.20
# ..          ...   ...     ...    ...   ...     ...   ...     ...         ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  4.0770       29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  3.4005       24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1.7820       19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.8780       21.78
# 500       20.00  5.00    male     no   Fri   Lunch     3  2.0000       22.00
#
# [245 rows x 9 columns]

# %% [markdown]
# # Data Transformation

# %% [raw]
# - any activity to change format of data
# - it also includes combining multiple dataframes

# %%
df  =pd.read_csv("E:\\DUCAT_PYTHON COURSE\\dataset\\analysis\\emp.txt")

# %%
df
# Out:
#    empid empname  empsal
# 0      1    sonu   10000
# 1      2    monu   12000
# 2      3  chintu    8000
# 3      4   pintu   11000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.index=df.empid

# %%
df
# Out:
#        empid empname  empsal
# empid
# 1          1    sonu   10000
# 2          2    monu   12000
# 3          3  chintu    8000
# 4          4   pintu   11000

# %%
df.drop('empid',axis=1,inplace=True)

# %%
df
# Out:
#       empname  empsal
# empid
# 1        sonu   10000
# 2        monu   12000
# 3      chintu    8000
# 4       pintu   11000

# %%
df.loc[3]
# Out:
# empname    chintu
# empsal       8000
# Name: 3, dtype: object

# %%
df.loc[[3]]
# Out:
#       empname  empsal
# empid
# 3      chintu    8000

# %%
try:
    eid=int(input("enter empid:"))
    print(df.loc[[3]]) 
except:
    print("eid does not exist")
# Out:
# enter empid:3
#       empname  empsal
# empid
# 3      chintu    8000

# %%
df  =pd.read_csv("E:\\DUCAT_PYTHON COURSE\\dataset\\analysis\\restaurant.csv")

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby('time')[['day']].count()
# Out:
#         day
# time
# Dinner  176
# Lunch    68

# %%
df2=df.groupby('time')[['tip']].agg(['min','max','mean','sum'])
df2
# Out:
#          tip
#          min   max      mean     sum
# time
# Dinner  1.00  10.0  3.102670  546.07
# Lunch   1.25   6.7  2.728088  185.51

# %%
df2.loc['Dinner']
# Out:
# tip  min       1.00000
#      max      10.00000
#      mean      3.10267
#      sum     546.07000
# Name: Dinner, dtype: float64

# %%
df_cs=pd.read_csv("E:\\DUCAT_PYTHON COURSE\\dataset\\analysis\\cs.txt")
df_cs
# Out:
#    roll   name  age
# 0   105  dhoni   22
# 1   106   pant   19

# %%
df_ec=pd.read_csv("E:\\DUCAT_PYTHON COURSE\\dataset\\analysis\\ec.txt")
df_ec
# Out:
#    roll   name  age
# 0   108  dhoni   23
# 1   106   shaw   18

# %%
df_res=pd.concat([df_cs,df_ec],axis=0,ignore_index=True)
df_res
# Out:
#    roll   name  age
# 0   105  dhoni   22
# 1   106   pant   19
# 2   108  dhoni   23
# 3   106   shaw   18

# %%
df_res.loc[0]
# Out:
# roll      105
# name    dhoni
# age        22
# Name: 0, dtype: object

# %%
df_res=pd.concat([df_cs,df_ec],axis=0,ignore_index=True,sort=True)
df_res
# Out:
#    age   name  roll
# 0   22  dhoni   105
# 1   19   pant   106
# 2   23  dhoni   108
# 3   18   shaw   106

# %%
df_res=pd.concat([df_cs,df_ec],axis=0)
df_res
# Out:
#    roll   name  age
# 0   105  dhoni   22
# 1   106   pant   19
# 0   108  dhoni   23
# 1   106   shaw   18

# %%
df_res.reset_index()
# Out:
#    index  roll   name  age
# 0      0   105  dhoni   22
# 1      1   106   pant   19
# 2      0   108  dhoni   23
# 3      1   106   shaw   18

# %%
df_res.reset_index(drop=True)
# Out:
#    roll   name  age
# 0   105  dhoni   22
# 1   106   pant   19
# 2   108  dhoni   23
# 3   106   shaw   18

# %%
#df3=pd.DataFrame({'roll':[1,2,3],'name':['a','b','c','d']})
#df4=pd.DataFrame({'age':[10,20,30],'branch':['a','b','c','d']})
#df3

# %%
df.cs.join(df.ec)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1100\3642119390.py in <module>
# ----> 1 df.cs.join(df.ec)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cs'
