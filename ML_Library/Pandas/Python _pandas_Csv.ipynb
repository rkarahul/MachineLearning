# %% [markdown]
# # ❤❤  How to Read Csv File In Pandas

# %% [markdown]
# # (Comma Separated Value`s)

# %%
import pandas as pd

# %% [raw]
#                                             Csv file
# >comma Separted values.
# >it is a text file
# ex - 101,102,103,rahul
#      104,105,106,rka

# %%
pd.read_csv('E:\MACHIN LEARING\DataSets\student_results.csv')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
pd.read_csv('E:\MACHIN LEARING\DataSets\Top-10-IT-Companies-in-India.csv')
# Out:
#   Top 10 IT Companies in India
# 0                          TCS
# 1                      Infosys
# 2                Tech Mahindra
# 3                        Wipro
# 4             HCL Technologies
# 5                 L&T Infotech
# 6                     Mindtree
# 7                      Mphasis
# 8    Oracle Financial Services
# 9                  Rotla India

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\HP\ML_PANDAS_LIB

# %%
df = pd.read_excel('E:\MACHIN LEARING\DataSets\Book1.xlsx',sheet_name = 'Sheet1',header=None,)
df
# Out:
#      0   1       2
# 0  101  20    sonu
# 1  102  25    monu
# 2  200  15  chintu

# %%
df = pd.read_excel('E:\MACHIN LEARING\DataSets\Book1.xlsx',sheet_name = 'Sheet4')
df
# Out:
#    Roll  age    name
# 0   101   20    sonu
# 1   102   25    monu
# 2   200   15  chintu

# %%
dict_dfs = pd.read_excel('E:\MACHIN LEARING\DataSets\Book1.xlsx',sheet_name = 'Sheet4')
dict_dfs.key()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7116\1469999352.py in <module>
#       1 dict_dfs = pd.read_excel('E:\MACHIN LEARING\DataSets\Book1.xlsx',sheet_name = 'Sheet4')
# ----> 2 dict_dfs.key()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'key'

# %%
df = pd.read_csv('E:\MACHIN LEARING\DataSets\Fortune_10.csv',nrows=8,skiprows=[1,3])
df
# Out:
#    ID            Name             Industry  Inception       Revenue  \
# 0   2       Stripfind   Financial Services       2010  $12,329,371
# 1   4        Mattouch          IT Services       2013  $14,026,934
# 2   5       Techdrill               Health       2009  $10,573,990
# 3   6        Techline               Health       2006  $13,898,119
# 4   7         Cityace               Health       2010   $9,254,614
# 5   8  Kayelectronics               Health       2009   $9,451,943
# 6   9         Ganzlax          IT Services       2011  $14,001,180
# 7  10     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0    916,455 Dollars  11412916    20%
# 1  7,429,377 Dollars   6597557    26%
# 2  7,435,363 Dollars   3138627     8%
# 3  5,470,303 Dollars   8427816    23%
# 4  6,249,498 Dollars   3005116     6%
# 5  3,878,113 Dollars   5573830     4%
# 6                NaN  11901180    18%
# 7  5,635,276 Dollars   5453060     7%

# %%
df = pd.read_csv('E:\MACHIN LEARING\DataSets\Fortune_10.csv',nrows=8,skiprows=range(1,6))
df
# Out:
#    ID            Name             Industry  Inception       Revenue  \
# 0   6        Techline               Health       2006  $13,898,119
# 1   7         Cityace               Health       2010   $9,254,614
# 2   8  Kayelectronics               Health       2009   $9,451,943
# 3   9         Ganzlax          IT Services       2011  $14,001,180
# 4  10     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  5,470,303 Dollars   8427816    23%
# 1  6,249,498 Dollars   3005116     6%
# 2  3,878,113 Dollars   5573830     4%
# 3                NaN  11901180    18%
# 4  5,635,276 Dollars   5453060     7%

# %%
#df = pd.read_csv("E:\\MACHIN LEARING\\DataSets\\test_identity.csv",usecols="A:D")
df

# %% [markdown]
# # How to load csv file

# %%
df = pd.read_csv("E:\MACHIN LEARING\DataSets\Fortune_10.csv",header=None,name=['1','2','3','4','5','6','7'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7116\1840789472.py in <module>
# ----> 1 df = pd.read_csv("E:\MACHIN LEARING\DataSets\Fortune_10.csv",header=None,name=['1','2','3','4','5','6','7'])
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'name'

# %%
df = pd.read_csv("E:\MACHIN LEARING\DataSets\Fortune_10.csv",header=None,sep=':')
df
# Out:
#                                                     0
# 0   ID,Name,Industry,Inception,Revenue,Expenses,Pr...
# 1   1,Lamtone,IT Services,2009,"$11,757,018 ","6,4...
# 2   2,Stripfind,Financial Services,2010,"$12,329,3...
# 3   3,Canecorporation,Health,2012,"$10,597,009 ","...
# 4   4,Mattouch,IT Services,2013,"$14,026,934 ","7,...
# 5   5,Techdrill,Health,2009,"$10,573,990 ","7,435,...
# 6   6,Techline,Health,2006,"$13,898,119 ","5,470,3...
# 7   7,Cityace,Health,2010,"$9,254,614 ","6,249,498...
# 8   8,Kayelectronics,Health,2009,"$9,451,943 ","3,...
# 9   9,Ganzlax,IT Services,2011,"$14,001,180 ",,119...
# 10  10,Trantraxlax,Government Services,2011,"$11,0...

# %%
df = pd.read_csv("E:\MACHIN LEARING\DataSets\Fortune_10.csv",header=None,sep = "\t")
df
# Out:
#                                                     0
# 0   ID,Name,Industry,Inception,Revenue,Expenses,Pr...
# 1   1,Lamtone,IT Services,2009,"$11,757,018 ","6,4...
# 2   2,Stripfind,Financial Services,2010,"$12,329,3...
# 3   3,Canecorporation,Health,2012,"$10,597,009 ","...
# 4   4,Mattouch,IT Services,2013,"$14,026,934 ","7,...
# 5   5,Techdrill,Health,2009,"$10,573,990 ","7,435,...
# 6   6,Techline,Health,2006,"$13,898,119 ","5,470,3...
# 7   7,Cityace,Health,2010,"$9,254,614 ","6,249,498...
# 8   8,Kayelectronics,Health,2009,"$9,451,943 ","3,...
# 9   9,Ganzlax,IT Services,2011,"$14,001,180 ",,119...
# 10  10,Trantraxlax,Government Services,2011,"$11,0...

# %% [markdown]
# # Missing Value

# %% [raw]
# database = NULL
# pandas  = NaN
